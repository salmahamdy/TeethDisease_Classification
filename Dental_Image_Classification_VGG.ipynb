# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models, optimizers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img_height, img_width = 224, 224
batch_size = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/Teeth DataSet/Teeth_Dataset/Training",
    image_size=(img_height, img_width),
    batch_size=batch_size
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/Teeth DataSet/Teeth_Dataset/Validation",
    image_size=(img_height, img_width),
    batch_size=batch_size
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/Teeth DataSet/Teeth_Dataset/Testing",
    image_size=(img_height, img_width),
    batch_size=batch_size
)

# Extract class names
class_names = train_ds.class_names
print("Classes:", class_names)
num_classes = len(class_names)

normalization_layer = layers.Rescaling(1./255)

train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds   = val_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds  = test_ds.map(lambda x, y: (normalization_layer(x), y))
# Out:
# Found 3087 files belonging to 7 classes.
# Found 1028 files belonging to 7 classes.
# Found 1028 files belonging to 7 classes.
# Classes: ['CaS', 'CoS', 'Gum', 'MC', 'OC', 'OLP', 'OT']

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models, optimizers

# VGG16-based model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation='relu')(x)
predictions = layers.Dense(num_classes, activation='softmax')(x)

model = models.Model(inputs=base_model.input, outputs=predictions)

model.summary()

# Compile
model.compile(optimizer=optimizers.Adam(learning_rate=1e-3),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100
)


# Save model
model.save("Dental_VGG16_finetuned.h5")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,913,607 (56.89 MB)
#  Trainable params: 198,919 (777.03 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Epoch 1/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 812s 8s/step - accuracy: 0.2052 - loss: 1.9069 - val_accuracy: 0.4008 - val_loss: 1.5284
# Epoch 2/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.4318 - loss: 1.5072 - val_accuracy: 0.5496 - val_loss: 1.3013
# Epoch 3/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 45s 277ms/step - accuracy: 0.4935 - loss: 1.3198 - val_accuracy: 0.5905 - val_loss: 1.1733
# Epoch 4/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.5501 - loss: 1.2172 - val_accuracy: 0.6119 - val_loss: 1.0635
# Epoch 5/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 230ms/step - accuracy: 0.6014 - loss: 1.1164 - val_accuracy: 0.6206 - val_loss: 1.0130
# Epoch 6/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 282ms/step - accuracy: 0.6129 - loss: 1.0450 - val_accuracy: 0.6274 - val_loss: 1.0180
# Epoch 7/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 277ms/step - accuracy: 0.6222 - loss: 1.0116 - val_accuracy: 0.6926 - val_loss: 0.8705
# Epoch 8/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 278ms/step - accuracy: 0.6761 - loss: 0.9234 - val_accuracy: 0.6770 - val_loss: 0.9354
# Epoch 9/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.6694 - loss: 0.8832 - val_accuracy: 0.7111 - val_loss: 0.8279
# Epoch 10/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 230ms/step - accuracy: 0.6822 - loss: 0.8470 - val_accuracy: 0.7082 - val_loss: 0.7998
# Epoch 11/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.7145 - loss: 0.7708 - val_accuracy: 0.7364 - val_loss: 0.7312
# Epoch 12/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 228ms/step - accuracy: 0.7127 - loss: 0.7523 - val_accuracy: 0.7315 - val_loss: 0.7287
# Epoch 13/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 282ms/step - accuracy: 0.7368 - loss: 0.6997 - val_accuracy: 0.7685 - val_loss: 0.6361
# Epoch 14/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 277ms/step - accuracy: 0.7577 - loss: 0.6669 - val_accuracy: 0.7918 - val_loss: 0.6144
# Epoch 15/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 281ms/step - accuracy: 0.7654 - loss: 0.6379 - val_accuracy: 0.7996 - val_loss: 0.5856
# Epoch 16/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.7574 - loss: 0.6147 - val_accuracy: 0.7967 - val_loss: 0.5749
# Epoch 17/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 279ms/step - accuracy: 0.7854 - loss: 0.5971 - val_accuracy: 0.8006 - val_loss: 0.5883
# Epoch 18/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.7937 - loss: 0.5767 - val_accuracy: 0.7802 - val_loss: 0.5690
# Epoch 19/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 232ms/step - accuracy: 0.7964 - loss: 0.5653 - val_accuracy: 0.7695 - val_loss: 0.5968
# Epoch 20/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.8131 - loss: 0.5177 - val_accuracy: 0.8307 - val_loss: 0.4876
# Epoch 21/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 278ms/step - accuracy: 0.8122 - loss: 0.5233 - val_accuracy: 0.8249 - val_loss: 0.5159
# Epoch 22/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - accuracy: 0.8027 - loss: 0.4979 - val_accuracy: 0.8375 - val_loss: 0.4843
# Epoch 23/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 280ms/step - accuracy: 0.8337 - loss: 0.4389 - val_accuracy: 0.8541 - val_loss: 0.4568
# Epoch 24/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - accuracy: 0.8209 - loss: 0.4637 - val_accuracy: 0.8444 - val_loss: 0.4453
# Epoch 25/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 279ms/step - accuracy: 0.8321 - loss: 0.4460 - val_accuracy: 0.8521 - val_loss: 0.4177
# Epoch 26/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.8483 - loss: 0.4029 - val_accuracy: 0.8424 - val_loss: 0.4623
# Epoch 27/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 278ms/step - accuracy: 0.8423 - loss: 0.4284 - val_accuracy: 0.8589 - val_loss: 0.4192
# Epoch 28/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.8335 - loss: 0.4538 - val_accuracy: 0.8502 - val_loss: 0.4186
# Epoch 29/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 231ms/step - accuracy: 0.8448 - loss: 0.4138 - val_accuracy: 0.8667 - val_loss: 0.4027
# Epoch 30/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 229ms/step - accuracy: 0.8299 - loss: 0.4437 - val_accuracy: 0.8667 - val_loss: 0.4016
# Epoch 31/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.8657 - loss: 0.3842 - val_accuracy: 0.8716 - val_loss: 0.3839
# Epoch 32/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 229ms/step - accuracy: 0.8647 - loss: 0.3599 - val_accuracy: 0.8638 - val_loss: 0.3878
# Epoch 33/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 282ms/step - accuracy: 0.8574 - loss: 0.3697 - val_accuracy: 0.8531 - val_loss: 0.3998
# Epoch 34/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 278ms/step - accuracy: 0.8631 - loss: 0.3841 - val_accuracy: 0.8716 - val_loss: 0.3661
# Epoch 35/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.8627 - loss: 0.3799 - val_accuracy: 0.8823 - val_loss: 0.3640
# Epoch 36/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 230ms/step - accuracy: 0.8700 - loss: 0.3681 - val_accuracy: 0.8833 - val_loss: 0.3509
# Epoch 37/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.8620 - loss: 0.3666 - val_accuracy: 0.8852 - val_loss: 0.3533
# Epoch 38/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - accuracy: 0.8807 - loss: 0.3351 - val_accuracy: 0.8716 - val_loss: 0.3530
# Epoch 39/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 277ms/step - accuracy: 0.8749 - loss: 0.3402 - val_accuracy: 0.8745 - val_loss: 0.3559
# Epoch 40/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 231ms/step - accuracy: 0.8623 - loss: 0.3453 - val_accuracy: 0.8687 - val_loss: 0.3817
# Epoch 41/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.8763 - loss: 0.3226 - val_accuracy: 0.8560 - val_loss: 0.3800
# Epoch 42/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 229ms/step - accuracy: 0.8825 - loss: 0.3196 - val_accuracy: 0.8765 - val_loss: 0.3541
# Epoch 43/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 282ms/step - accuracy: 0.8592 - loss: 0.3577 - val_accuracy: 0.8881 - val_loss: 0.3434
# Epoch 44/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - accuracy: 0.8757 - loss: 0.3277 - val_accuracy: 0.8716 - val_loss: 0.3493
# Epoch 45/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.8923 - loss: 0.2990 - val_accuracy: 0.8881 - val_loss: 0.3226
# Epoch 46/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 280ms/step - accuracy: 0.8868 - loss: 0.3143 - val_accuracy: 0.8969 - val_loss: 0.3117
# Epoch 47/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 36s 230ms/step - accuracy: 0.8764 - loss: 0.3032 - val_accuracy: 0.8901 - val_loss: 0.3447
# Epoch 48/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.8836 - loss: 0.2994 - val_accuracy: 0.8881 - val_loss: 0.3276
# Epoch 49/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - accuracy: 0.8976 - loss: 0.2804 - val_accuracy: 0.8969 - val_loss: 0.3142
# Epoch 50/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - accuracy: 0.9055 - loss: 0.2631 - val_accuracy: 0.8911 - val_loss: 0.2867
# Epoch 51/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 231ms/step - accuracy: 0.8792 - loss: 0.3078 - val_accuracy: 0.9047 - val_loss: 0.3072
# Epoch 52/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - accuracy: 0.8815 - loss: 0.3062 - val_accuracy: 0.9066 - val_loss: 0.2769
# Epoch 53/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 282ms/step - accuracy: 0.8854 - loss: 0.3087 - val_accuracy: 0.8998 - val_loss: 0.3083
# Epoch 54/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 277ms/step - accuracy: 0.8971 - loss: 0.2799 - val_accuracy: 0.8745 - val_loss: 0.3528
# Epoch 55/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.8935 - loss: 0.2741 - val_accuracy: 0.9173 - val_loss: 0.2737
# Epoch 56/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9005 - loss: 0.2749 - val_accuracy: 0.8911 - val_loss: 0.3413
# Epoch 57/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.8883 - loss: 0.2946 - val_accuracy: 0.8658 - val_loss: 0.3738
# Epoch 58/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 278ms/step - accuracy: 0.8765 - loss: 0.3152 - val_accuracy: 0.9163 - val_loss: 0.2730
# Epoch 59/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.9091 - loss: 0.2562 - val_accuracy: 0.8969 - val_loss: 0.2948
# Epoch 60/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.8998 - loss: 0.2637 - val_accuracy: 0.8930 - val_loss: 0.3144
# Epoch 61/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 45s 277ms/step - accuracy: 0.8930 - loss: 0.2766 - val_accuracy: 0.9037 - val_loss: 0.2701
# Epoch 62/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.9165 - loss: 0.2293 - val_accuracy: 0.9066 - val_loss: 0.2637
# Epoch 63/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.9030 - loss: 0.2588 - val_accuracy: 0.8920 - val_loss: 0.3627
# Epoch 64/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.8945 - loss: 0.2677 - val_accuracy: 0.9173 - val_loss: 0.2696
# Epoch 65/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.9089 - loss: 0.2376 - val_accuracy: 0.9086 - val_loss: 0.3053
# Epoch 66/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 231ms/step - accuracy: 0.8893 - loss: 0.2830 - val_accuracy: 0.9222 - val_loss: 0.2649
# Epoch 67/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 231ms/step - accuracy: 0.8970 - loss: 0.2651 - val_accuracy: 0.8930 - val_loss: 0.3114
# Epoch 68/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 45s 277ms/step - accuracy: 0.9165 - loss: 0.2215 - val_accuracy: 0.9183 - val_loss: 0.2674
# Epoch 69/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 280ms/step - accuracy: 0.9197 - loss: 0.2278 - val_accuracy: 0.8794 - val_loss: 0.3434
# Epoch 70/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 36s 230ms/step - accuracy: 0.8868 - loss: 0.3294 - val_accuracy: 0.8881 - val_loss: 0.3212
# Epoch 71/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 281ms/step - accuracy: 0.8905 - loss: 0.3056 - val_accuracy: 0.8774 - val_loss: 0.3105
# Epoch 72/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 277ms/step - accuracy: 0.9012 - loss: 0.2715 - val_accuracy: 0.9037 - val_loss: 0.3028
# Epoch 73/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 36s 230ms/step - accuracy: 0.9108 - loss: 0.2245 - val_accuracy: 0.9202 - val_loss: 0.2692
# Epoch 74/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.9220 - loss: 0.1947 - val_accuracy: 0.9125 - val_loss: 0.2915
# Epoch 75/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 228ms/step - accuracy: 0.9239 - loss: 0.2074 - val_accuracy: 0.9115 - val_loss: 0.2694
# Epoch 76/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 235ms/step - accuracy: 0.9175 - loss: 0.2192 - val_accuracy: 0.9183 - val_loss: 0.2596
# Epoch 77/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 228ms/step - accuracy: 0.9106 - loss: 0.2403 - val_accuracy: 0.9056 - val_loss: 0.3209
# Epoch 78/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.9079 - loss: 0.2366 - val_accuracy: 0.9047 - val_loss: 0.3220
# Epoch 79/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 231ms/step - accuracy: 0.9005 - loss: 0.2614 - val_accuracy: 0.9125 - val_loss: 0.2698
# Epoch 80/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 45s 276ms/step - accuracy: 0.9093 - loss: 0.2446 - val_accuracy: 0.9144 - val_loss: 0.2796
# Epoch 81/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 234ms/step - accuracy: 0.9073 - loss: 0.2404 - val_accuracy: 0.9018 - val_loss: 0.2943
# Epoch 82/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.9166 - loss: 0.2168 - val_accuracy: 0.9066 - val_loss: 0.2474
# Epoch 83/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 228ms/step - accuracy: 0.9142 - loss: 0.2471 - val_accuracy: 0.8911 - val_loss: 0.3204
# Epoch 84/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - accuracy: 0.9141 - loss: 0.2218 - val_accuracy: 0.8998 - val_loss: 0.3057
# Epoch 85/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 231ms/step - accuracy: 0.9109 - loss: 0.2614 - val_accuracy: 0.9193 - val_loss: 0.2444
# Epoch 86/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 278ms/step - accuracy: 0.9125 - loss: 0.2208 - val_accuracy: 0.8940 - val_loss: 0.3334
# Epoch 87/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 280ms/step - accuracy: 0.9111 - loss: 0.2352 - val_accuracy: 0.9144 - val_loss: 0.2876
# Epoch 88/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 280ms/step - accuracy: 0.9309 - loss: 0.2066 - val_accuracy: 0.9202 - val_loss: 0.2703
# Epoch 89/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 36s 229ms/step - accuracy: 0.9380 - loss: 0.1838 - val_accuracy: 0.9241 - val_loss: 0.2496
# Epoch 90/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - accuracy: 0.9154 - loss: 0.2124 - val_accuracy: 0.9066 - val_loss: 0.2638
# Epoch 91/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 23s 233ms/step - accuracy: 0.9362 - loss: 0.1710 - val_accuracy: 0.9086 - val_loss: 0.3230
# Epoch 92/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 228ms/step - accuracy: 0.9299 - loss: 0.1887 - val_accuracy: 0.9154 - val_loss: 0.3072
# Epoch 93/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 282ms/step - accuracy: 0.9125 - loss: 0.2393 - val_accuracy: 0.9095 - val_loss: 0.2705
# Epoch 94/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 278ms/step - accuracy: 0.9262 - loss: 0.2177 - val_accuracy: 0.9193 - val_loss: 0.2542
# Epoch 95/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 36s 230ms/step - accuracy: 0.9151 - loss: 0.2142 - val_accuracy: 0.9193 - val_loss: 0.2912
# Epoch 96/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - accuracy: 0.9095 - loss: 0.2308 - val_accuracy: 0.9144 - val_loss: 0.2470
# Epoch 97/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - accuracy: 0.9097 - loss: 0.2324 - val_accuracy: 0.9173 - val_loss: 0.2389
# Epoch 98/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 282ms/step - accuracy: 0.9214 - loss: 0.2019 - val_accuracy: 0.9261 - val_loss: 0.2493
# Epoch 99/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - accuracy: 0.9277 - loss: 0.2200 - val_accuracy: 0.8930 - val_loss: 0.3589
# Epoch 100/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.9086 - loss: 0.2627 - val_accuracy: 0.9261 - val_loss: 0.2312
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# --- Evaluation on Test Set ---
test_loss, test_acc = model.evaluate(test_ds)
print("Test Accuracy:", test_acc)
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 218s 7s/step - accuracy: 0.9223 - loss: 0.2283
# Test Accuracy: 0.9309338331222534

# %%
def plot_learning_curve(history, metrics):
    acc = history.history[metrics]
    val_acc = history.history[f'val_{metrics}']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(acc))

    plt.figure(figsize=(5,3))
    plt.plot(epochs, acc, label=f'training {metrics}')
    plt.plot(epochs, val_acc, label=f'validation {metrics}')
    plt.grid()
    plt.xlabel('Epochs')
    plt.ylabel(metrics)
    plt.legend()

    plt.figure(figsize=(5,3))
    plt.plot(epochs, loss, label='training loss')
    plt.plot(epochs, val_loss, label='validation loss')
    plt.grid()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# %%
plot_learning_curve(history, metrics='accuracy')

# %%
train_result = model.evaluate(train_ds)
test_result = model.evaluate(test_ds)

print("Train Accuracy:", train_result[1])
print("Test Accuracy:", test_result[1])
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 18s 180ms/step - accuracy: 0.9923 - loss: 0.0327
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - accuracy: 0.9262 - loss: 0.2097
# Train Accuracy: 0.989957869052887
# Test Accuracy: 0.9309338331222534

# %% [markdown]
# ### Confusion Matrix, F1 Score, and ROC Curve

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np

y_true = []
y_pred_probs = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())
    y_pred_probs.extend(model.predict(images))

y_true = np.array(y_true)
y_pred_probs = np.array(y_pred_probs)
y_pred = np.argmax(y_pred_probs, axis=1)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

# Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# ROC Curve
plt.figure(figsize=(8, 6))
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true == i, y_pred_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'ROC curve for class {class_names[i]} (area = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 999ms/step
# Confusion Matrix:
# [[151   0   0   0   4   4   1]
#  [  2 144   0   1   0   2   0]
#  [  1   0 115   3   0   0   1]
#  [  0   0   7 157   4   9   3]
#  [  0   0   0   0 102   4   2]
#  [  3   0   3   0   4 167   3]
#  [  0   0   0   3   2   5 121]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          CaS       0.96      0.94      0.95       160
#          CoS       1.00      0.97      0.98       149
#          Gum       0.92      0.96      0.94       120
#           MC       0.96      0.87      0.91       180
#           OC       0.88      0.94      0.91       108
#          OLP       0.87      0.93      0.90       180
#           OT       0.92      0.92      0.92       131
#
#     accuracy                           0.93      1028
#    macro avg       0.93      0.93      0.93      1028
# weighted avg       0.93      0.93      0.93      1028
